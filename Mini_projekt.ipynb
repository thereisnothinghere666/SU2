# %% [markdown]
# <a href="https://colab.research.google.com/github/thereisnothinghere666/SU2/blob/master/Mini_projekt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Instalacja SU2

# %% [markdown]
# clone repo

# %%
# !git clone https://github.com/su2code/SU2.git
# Out:
# Cloning into 'SU2'...
# Updating files:  23% (609/2553)
# Updating files:  24% (613/2553)
# Updating files:  25% (639/2553)
# Updating files:  26% (664/2553)
# Updating files:  27% (690/2553)
# Updating files:  28% (715/2553)
# Updating files:  29% (741/2553)
# Updating files:  30% (766/2553)
# Updating files:  30% (782/2553)
# Updating files:  31% (792/2553)
# Updating files:  32% (817/2553)
# Updating files:  33% (843/2553)
# Updating files:  34% (869/2553)
# Updating files:  35% (894/2553)
# Updating files:  35% (914/2553)
# Updating files:  36% (920/2553)
# Updating files:  37% (945/2553)
# Updating files:  38% (971/2553)
# Updating files:  39% (996/2553)
# Updating files:  40% (1022/2553)
# Updating files:  41% (1047/2553)
# Updating files:  42% (1073/2553)
# Updating files:  43% (1098/2553)
# Updating files:  44% (1124/2553)
# Updating files:  45% (1149/2553)
# Updating files:  46% (1175/2553)
# Updating files:  47% (1200/2553)
# Updating files:  47% (1218/2553)
# ...

# %% [markdown]
# wejście do katalogu

# %%
# %cd SU2
# Out:
# C:\Users\Michał\PycharmProjects\SU2\SU2

# %% [markdown]
# instalacja zależności

# %%
# !apt-get update
# !apt-get install -y cmake g++ mpich libmpich-dev python3-dev
# Out:
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# build SU2

# %%
# !python meson.py setup build
# Out:
# Initialize submodule C:\Users\Michał\PycharmProjects\SU2\SU2\externals\codi using git ...
# Submodule path 'externals/codi': checked out 'a0725b2bfd172e741a07f96b041a5ddf88d441d7'
# Initialize submodule C:\Users\Michał\PycharmProjects\SU2\SU2\externals\medi using git ...
# Submodule path 'externals/medi': checked out '0cfaf96e7a31a5a8941b97f84198da03a8f8bd7a'
# Initialize submodule C:\Users\Michał\PycharmProjects\SU2\SU2\externals\opdi using git ...
# Submodule path 'externals/opdi': checked out '294807b0111ce241cda97db62f80cdd5012d9381'
# Initialize submodule C:\Users\Michał\PycharmProjects\SU2\SU2\externals\meson using git ...
# Submodule path 'externals/meson': checked out '5a82ea0501736a666ca9cc003ea0774f8219fd65'
# Initialize submodule C:\Users\Michał\PycharmProjects\SU2\SU2\externals\ninja using git ...
# Submodule path 'externals/ninja': checked out 'b4d51f6ed5bed09dd2b70324df0d9cb4ecad2638'
# ...

# %%
# !./ninja -C build install
# Out:
# '.' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ustawienie środowiska

# %%
import os

os.environ['SU2_RUN'] = '/content/SU2/build/bin'
os.environ['SU2_HOME'] = '/content/SU2'

os.environ['PATH'] += ':/content/SU2/build/bin'

# %% [markdown]
# test działania

# %%
# !SU2_CFD
# Out:
# 'SU2_CFD' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# tutorial

# %%
# %cd /content/SU2/TestCases
# Out:
# [WinError 3] System nie może odnaleźć określonej ścieżki: '/content/SU2/TestCases'
# C:\Users\Michał\PycharmProjects\SU2\SU2

# %% [markdown]
# uruchom CFD

# %%
# !find /content/SU2 -name "*.cfg" | head -20
# Out:
# 'head' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# %cd /content/SU2/QuickStart
# Out:
# [WinError 3] System nie może odnaleźć określonej ścieżki: '/content/SU2/QuickStart'
# C:\Users\Michał\PycharmProjects\SU2\SU2

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !find /content/SU2 -name "SU2_CFD"
# Out:
# FIND: Invalid switch

# %%
# !/content/SU2/build/SU2_CFD inv_NACA0012.cfg
# Out:
# System nie mo�e odnale�� okre�lonej �cie�ki.

# %%
# !find /content/SU2/build -type f -name "SU2_CFD"
# Out:
# FIND: Invalid switch

# %%
# !export OMPI_MCA_osc=pt2pt && /content/SU2/build/SU2_CFD/src/SU2_CFD inv_NACA0012.cfg
# Out:
# 'export' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## Projekt

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd

data = pd.read_csv("surface_flow.csv")

data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 3
#       1 import pandas as pd
#       2
# ----> 3 data = pd.read_csv("surface_flow.csv")
#       4
#       5 data.head()
#
# File ~\PycharmProjects\SU2\.venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...
